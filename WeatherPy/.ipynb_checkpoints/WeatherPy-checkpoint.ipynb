# %% [markdown]
# ----
# # **Python API Homework - WeatherPy**
# ### Submitted by : Sheetal Bongale | UT Data Analysis and Visualization
# ##### *This Jupyter notebook has a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator using CityPy, a simple Python library, and the OpenWeatherMap API.*
# ---
#
# <b> Note: </b> Please find the written analysis of this data at the bottom of this jupyter notebook.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import date
import seaborn as sns

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Define a function to perfome API Calls
def get_weather(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/weather"
    r = requests.get(url, params={"appid": api_key,"q": city, "units":"imperial"})
    if r.status_code == 200:        
        response = r.json()
        return response
    else:
        print("City not found. Skipping...")
        return None

# %%
# Successive API calls and print log for each city
city_data = []
record_count = 1
set_count = 1

print("Beginning Data Retrieval\n------------------------")

# Loop through the cities
for i,city in enumerate(cities):
    if (i%50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    print("Processing Record %s of Set %s | %s" %(record_count, set_count, city))
    record_count += 1

    city_results = get_weather(city, api_key)
    if city_results:
        city_data.append(city_results)
    
print("------------------------\nData Retrieval Complete\n------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | changde
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | dunedin
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | baruun-urt
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | xining
# Processing Record 8 of Set 1 | fort dodge
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | roald
# Processing Record 11 of Set 1 | juba
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | maunabo
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | guerrero negro
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | livny
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | dingle
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | port hardy
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | najran
# Processing Record 38 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 1 | kaabong
# Processing Record 40 of Set 1 | bandarbeyla
# Processing Record 41 of Set 1 | witu
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | nicholasville
# Processing Record 45 of Set 1 | caravelas
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | jinchang
# Processing Record 48 of Set 1 | yumen
# Processing Record 49 of Set 1 | gizo
# Processing Record 50 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 0 of Set 2 | sakakah
# City not found. Skipping...
# Processing Record 1 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 2 | sulangan
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | bahia blanca
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | magdagachi
# Processing Record 7 of Set 2 | mbarara
# Processing Record 8 of Set 2 | luena
# Processing Record 9 of Set 2 | gimli
# Processing Record 10 of Set 2 | asau
# City not found. Skipping...
# Processing Record 11 of Set 2 | taoudenni
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | shimoda
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | grindavik
# Processing Record 18 of Set 2 | hualmay
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | bilma
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | biltine
# Processing Record 31 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | kyzyl-suu
# Processing Record 34 of Set 2 | salalah
# Processing Record 35 of Set 2 | olinda
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | kilmez
# City not found. Skipping...
# Processing Record 40 of Set 2 | puri
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | lokosovo
# Processing Record 44 of Set 2 | bowen
# Processing Record 45 of Set 2 | scottsbluff
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | kaeo
# Processing Record 48 of Set 2 | gilgit
# Processing Record 49 of Set 2 | doha
# Processing Record 0 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | beringovskiy
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | kungurtug
# Processing Record 4 of Set 3 | tias
# Processing Record 5 of Set 3 | anan
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | hamilton
# Processing Record 8 of Set 3 | saint-augustin
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | ville-marie
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | buraydah
# Processing Record 13 of Set 3 | nantucket
# Processing Record 14 of Set 3 | prince george
# Processing Record 15 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 3 | alofi
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 3 | sandwick
# Processing Record 20 of Set 3 | banda aceh
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | jalu
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | marawi
# Processing Record 25 of Set 3 | baherden
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | akropong
# Processing Record 28 of Set 3 | luderitz
# Processing Record 29 of Set 3 | kushima
# Processing Record 30 of Set 3 | pacific grove
# Processing Record 31 of Set 3 | kharp
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | vestmannaeyjar
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | gardendale
# Processing Record 39 of Set 3 | lufilufi
# Processing Record 40 of Set 3 | almeirim
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 3 | puerto carreno
# Processing Record 43 of Set 3 | coruripe
# Processing Record 44 of Set 3 | vila franca do campo
# Processing Record 45 of Set 3 | del rio
# Processing Record 46 of Set 3 | northam
# Processing Record 47 of Set 3 | semme
# Processing Record 48 of Set 3 | pathein
# Processing Record 49 of Set 3 | mackay
# Processing Record 0 of Set 4 | kuryk
# Processing Record 1 of Set 4 | wilkie
# Processing Record 2 of Set 4 | lorengau
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | aldan
# Processing Record 5 of Set 4 | denpasar
# Processing Record 6 of Set 4 | kalmunai
# Processing Record 7 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | berlevag
# Processing Record 12 of Set 4 | anadyr
# Processing Record 13 of Set 4 | riyadh
# Processing Record 14 of Set 4 | baykit
# Processing Record 15 of Set 4 | chicama
# Processing Record 16 of Set 4 | taywarah
# Processing Record 17 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 4 | gotsu
# Processing Record 19 of Set 4 | yulara
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 4 | gadwal
# Processing Record 23 of Set 4 | lethem
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | bolshiye uki
# City not found. Skipping...
# Processing Record 26 of Set 4 | almaznyy
# Processing Record 27 of Set 4 | vostok
# Processing Record 28 of Set 4 | obo
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | aykhal
# Processing Record 31 of Set 4 | seredka
# Processing Record 32 of Set 4 | lushunkou
# City not found. Skipping...
# Processing Record 33 of Set 4 | celestun
# Processing Record 34 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 4 | bengkulu
# City not found. Skipping...
# Processing Record 36 of Set 4 | pimenta bueno
# Processing Record 37 of Set 4 | raudeberg
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | castro
# Processing Record 40 of Set 4 | tigil
# Processing Record 41 of Set 4 | churapcha
# Processing Record 42 of Set 4 | ramachandrapuram
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | mitsamiouli
# Processing Record 45 of Set 4 | kachug
# Processing Record 46 of Set 4 | mezen
# Processing Record 47 of Set 4 | aranos
# Processing Record 48 of Set 4 | belmonte
# Processing Record 49 of Set 4 | kruisfontein
# Processing Record 0 of Set 5 | guilin
# Processing Record 1 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | kasempa
# Processing Record 3 of Set 5 | arraial do cabo
# Processing Record 4 of Set 5 | uyskoye
# Processing Record 5 of Set 5 | qaqortoq
# Processing Record 6 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 5 | kavieng
# Processing Record 8 of Set 5 | jeremie
# Processing Record 9 of Set 5 | dedza
# Processing Record 10 of Set 5 | syasstroy
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | bentiu
# City not found. Skipping...
# Processing Record 15 of Set 5 | meulaboh
# Processing Record 16 of Set 5 | port-cartier
# Processing Record 17 of Set 5 | amahai
# Processing Record 18 of Set 5 | watertown
# Processing Record 19 of Set 5 | bairiki
# City not found. Skipping...
# Processing Record 20 of Set 5 | bay roberts
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | prachuap khiri khan
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | havoysund
# Processing Record 27 of Set 5 | cuamba
# Processing Record 28 of Set 5 | horsham
# Processing Record 29 of Set 5 | coffs harbour
# Processing Record 30 of Set 5 | uruguaiana
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | ostrovnoy
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | sao felix do xingu
# Processing Record 35 of Set 5 | lavrentiya
# Processing Record 36 of Set 5 | guozhen
# Processing Record 37 of Set 5 | pyapon
# Processing Record 38 of Set 5 | qaanaaq
# Processing Record 39 of Set 5 | moussoro
# Processing Record 40 of Set 5 | guanay
# Processing Record 41 of Set 5 | miranda
# Processing Record 42 of Set 5 | melo
# Processing Record 43 of Set 5 | yamada
# Processing Record 44 of Set 5 | ambon
# Processing Record 45 of Set 5 | snezhnogorsk
# Processing Record 46 of Set 5 | mahebourg
# Processing Record 47 of Set 5 | maumere
# Processing Record 48 of Set 5 | mehamn
# Processing Record 49 of Set 5 | haines junction
# Processing Record 0 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 6 | grand-santi
# Processing Record 2 of Set 6 | torbay
# Processing Record 3 of Set 6 | guiratinga
# Processing Record 4 of Set 6 | benghazi
# Processing Record 5 of Set 6 | cervo
# Processing Record 6 of Set 6 | emerald
# Processing Record 7 of Set 6 | salinopolis
# Processing Record 8 of Set 6 | banavar
# Processing Record 9 of Set 6 | biak
# Processing Record 10 of Set 6 | qui nhon
# City not found. Skipping...
# Processing Record 11 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 6 | ufa
# Processing Record 13 of Set 6 | christchurch
# Processing Record 14 of Set 6 | fort nelson
# Processing Record 15 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 6 | panguipulli
# Processing Record 17 of Set 6 | alta floresta
# Processing Record 18 of Set 6 | mana
# Processing Record 19 of Set 6 | norman wells
# Processing Record 20 of Set 6 | longyearbyen
# Processing Record 21 of Set 6 | goundi
# Processing Record 22 of Set 6 | kushnarenkovo
# Processing Record 23 of Set 6 | sibolga
# Processing Record 24 of Set 6 | boa vista
# Processing Record 25 of Set 6 | great yarmouth
# Processing Record 26 of Set 6 | lalmohan
# Processing Record 27 of Set 6 | casper
# Processing Record 28 of Set 6 | los llanos de aridane
# Processing Record 29 of Set 6 | dillon
# Processing Record 30 of Set 6 | xiuyan
# Processing Record 31 of Set 6 | turtas
# Processing Record 32 of Set 6 | sidi ali
# Processing Record 33 of Set 6 | lobatse
# Processing Record 34 of Set 6 | cayenne
# Processing Record 35 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 6 | nanakuli
# Processing Record 37 of Set 6 | aklavik
# Processing Record 38 of Set 6 | faya
# Processing Record 39 of Set 6 | westport
# Processing Record 40 of Set 6 | carstairs
# Processing Record 41 of Set 6 | kigoma
# Processing Record 42 of Set 6 | nazira
# Processing Record 43 of Set 6 | bhuj
# Processing Record 44 of Set 6 | pirovskoye
# Processing Record 45 of Set 6 | kirya
# City not found. Skipping...
# Processing Record 46 of Set 6 | acajutla
# Processing Record 47 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 48 of Set 6 | patnos
# Processing Record 49 of Set 6 | kenai
# Processing Record 0 of Set 7 | balykshi
# City not found. Skipping...
# Processing Record 1 of Set 7 | arti
# Processing Record 2 of Set 7 | struer
# Processing Record 3 of Set 7 | khor
# Processing Record 4 of Set 7 | zhezkazgan
# Processing Record 5 of Set 7 | saint-pierre
# Processing Record 6 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 7 of Set 7 | saint peters
# Processing Record 8 of Set 7 | ambulu
# Processing Record 9 of Set 7 | soyo
# Processing Record 10 of Set 7 | labuhan
# Processing Record 11 of Set 7 | namibe
# Processing Record 12 of Set 7 | durango
# Processing Record 13 of Set 7 | tecoanapa
# Processing Record 14 of Set 7 | narsaq
# Processing Record 15 of Set 7 | rafsanjan
# Processing Record 16 of Set 7 | karratha
# Processing Record 17 of Set 7 | port augusta
# Processing Record 18 of Set 7 | marsh harbour
# Processing Record 19 of Set 7 | katsuura
# Processing Record 20 of Set 7 | sitka
# Processing Record 21 of Set 7 | sierra vista
# Processing Record 22 of Set 7 | marzuq
# Processing Record 23 of Set 7 | vung tau
# Processing Record 24 of Set 7 | dwarka
# Processing Record 25 of Set 7 | constitucion
# Processing Record 26 of Set 7 | souillac
# Processing Record 27 of Set 7 | iqaluit
# Processing Record 28 of Set 7 | buluang
# Processing Record 29 of Set 7 | iracoubo
# Processing Record 30 of Set 7 | narrabri
# Processing Record 31 of Set 7 | awjilah
# Processing Record 32 of Set 7 | zastron
# Processing Record 33 of Set 7 | saint-joseph
# Processing Record 34 of Set 7 | sorland
# Processing Record 35 of Set 7 | porbandar
# Processing Record 36 of Set 7 | gamba
# Processing Record 37 of Set 7 | chimbote
# Processing Record 38 of Set 7 | nampula
# Processing Record 39 of Set 7 | kampene
# Processing Record 40 of Set 7 | yatou
# Processing Record 41 of Set 7 | novaya lyalya
# Processing Record 42 of Set 7 | altamira
# Processing Record 43 of Set 7 | bosaso
# Processing Record 44 of Set 7 | takoradi
# Processing Record 45 of Set 7 | kedrovyy
# Processing Record 46 of Set 7 | pudozh
# Processing Record 47 of Set 7 | bataipora
# Processing Record 48 of Set 7 | shibarghan
# City not found. Skipping...
# Processing Record 49 of Set 7 | lagoa
# Processing Record 0 of Set 8 | verkhoyansk
# Processing Record 1 of Set 8 | alice springs
# Processing Record 2 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 8 | okha
# Processing Record 4 of Set 8 | inuvik
# Processing Record 5 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 6 of Set 8 | abonnema
# Processing Record 7 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 8 | dodan
# Processing Record 9 of Set 8 | waipawa
# Processing Record 10 of Set 8 | angoche
# Processing Record 11 of Set 8 | sydney
# Processing Record 12 of Set 8 | udachnyy
# Processing Record 13 of Set 8 | jonuta
# Processing Record 14 of Set 8 | kamsack
# Processing Record 15 of Set 8 | cacoal
# Processing Record 16 of Set 8 | macau
# Processing Record 17 of Set 8 | peterhead
# Processing Record 18 of Set 8 | el carmen de bolivar
# Processing Record 19 of Set 8 | mount isa
# Processing Record 20 of Set 8 | novouzensk
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | chissamba
# City not found. Skipping...
# Processing Record 23 of Set 8 | corn island
# Processing Record 24 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 8 | mayumba
# Processing Record 26 of Set 8 | sola
# Processing Record 27 of Set 8 | pevek
# Processing Record 28 of Set 8 | olafsvik
# City not found. Skipping...
# Processing Record 29 of Set 8 | sangar
# Processing Record 30 of Set 8 | campina verde
# Processing Record 31 of Set 8 | jorpeland
# Processing Record 32 of Set 8 | nemuro
# Processing Record 33 of Set 8 | bukama
# Processing Record 34 of Set 8 | gushikawa
# Processing Record 35 of Set 8 | kununurra
# Processing Record 36 of Set 8 | ust-koksa
# Processing Record 37 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 8 | colborne
# Processing Record 39 of Set 8 | thinadhoo
# Processing Record 40 of Set 8 | hasaki
# Processing Record 41 of Set 8 | metu
# Processing Record 42 of Set 8 | fortuna
# Processing Record 43 of Set 8 | weyburn
# Processing Record 44 of Set 8 | araouane
# Processing Record 45 of Set 8 | deputatskiy
# Processing Record 46 of Set 8 | moose factory
# Processing Record 47 of Set 8 | southbridge
# Processing Record 48 of Set 8 | muros
# Processing Record 49 of Set 8 | faanui
# Processing Record 0 of Set 9 | mariinskiy posad
# Processing Record 1 of Set 9 | inta
# Processing Record 2 of Set 9 | termiz
# Processing Record 3 of Set 9 | esperance
# Processing Record 4 of Set 9 | gisborne
# Processing Record 5 of Set 9 | el alto
# Processing Record 6 of Set 9 | sao joao da barra
# Processing Record 7 of Set 9 | ereymentau
# Processing Record 8 of Set 9 | harper
# Processing Record 9 of Set 9 | sistranda
# Processing Record 10 of Set 9 | srednekolymsk
# Processing Record 11 of Set 9 | kutum
# Processing Record 12 of Set 9 | san cristobal
# Processing Record 13 of Set 9 | ambilobe
# Processing Record 14 of Set 9 | erzincan
# Processing Record 15 of Set 9 | nakuru
# Processing Record 16 of Set 9 | talcahuano
# Processing Record 17 of Set 9 | kenora
# Processing Record 18 of Set 9 | buta
# Processing Record 19 of Set 9 | pauini
# Processing Record 20 of Set 9 | balaguer
# Processing Record 21 of Set 9 | pitimbu
# Processing Record 22 of Set 9 | kloulklubed
# Processing Record 23 of Set 9 | nelson bay
# Processing Record 24 of Set 9 | resistencia
# Processing Record 25 of Set 9 | chingirlau
# Processing Record 26 of Set 9 | opuwo
# Processing Record 27 of Set 9 | talnakh
# Processing Record 28 of Set 9 | arica
# Processing Record 29 of Set 9 | la ronge
# Processing Record 30 of Set 9 | williams lake
# Processing Record 31 of Set 9 | pandan niog
# Processing Record 32 of Set 9 | russell
# Processing Record 33 of Set 9 | tabas
# Processing Record 34 of Set 9 | marathon
# Processing Record 35 of Set 9 | paamiut
# Processing Record 36 of Set 9 | bagdarin
# Processing Record 37 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of Set 9 | mahuta
# Processing Record 39 of Set 9 | chapais
# Processing Record 40 of Set 9 | iskateley
# Processing Record 41 of Set 9 | ziro
# Processing Record 42 of Set 9 | flinders
# Processing Record 43 of Set 9 | tombouctou
# Processing Record 44 of Set 9 | maputo
# Processing Record 45 of Set 9 | urcos
# Processing Record 46 of Set 9 | fengcheng
# Processing Record 47 of Set 9 | santa rosa
# Processing Record 48 of Set 9 | matara
# Processing Record 49 of Set 9 | saskylakh
# Processing Record 0 of Set 10 | vila velha
# Processing Record 1 of Set 10 | padang
# Processing Record 2 of Set 10 | valjevo
# Processing Record 3 of Set 10 | strelka
# Processing Record 4 of Set 10 | sur
# Processing Record 5 of Set 10 | mahajanga
# Processing Record 6 of Set 10 | voh
# Processing Record 7 of Set 10 | arman
# Processing Record 8 of Set 10 | benito juarez
# Processing Record 9 of Set 10 | bend
# Processing Record 10 of Set 10 | nagato
# Processing Record 11 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 10 | blackwater
# Processing Record 13 of Set 10 | maxixe
# Processing Record 14 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 10 | caucaia
# Processing Record 16 of Set 10 | bud
# Processing Record 17 of Set 10 | santo antonio do ica
# Processing Record 18 of Set 10 | balad
# Processing Record 19 of Set 10 | adrar
# Processing Record 20 of Set 10 | ginir
# Processing Record 21 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 10 | adelaide
# Processing Record 23 of Set 10 | mabaruma
# Processing Record 24 of Set 10 | bonthe
# Processing Record 25 of Set 10 | porto novo
# Processing Record 26 of Set 10 | libertador general san martin
# Processing Record 27 of Set 10 | abha
# Processing Record 28 of Set 10 | gwadar
# Processing Record 29 of Set 10 | broome
# Processing Record 30 of Set 10 | naze
# Processing Record 31 of Set 10 | mananara
# City not found. Skipping...
# Processing Record 32 of Set 10 | merauke
# Processing Record 33 of Set 10 | codajas
# Processing Record 34 of Set 10 | yanam
# Processing Record 35 of Set 10 | haimen
# Processing Record 36 of Set 10 | cabo san lucas
# Processing Record 37 of Set 10 | vila
# Processing Record 38 of Set 10 | champerico
# Processing Record 39 of Set 10 | leningradskiy
# Processing Record 40 of Set 10 | henties bay
# Processing Record 41 of Set 10 | kresttsy
# Processing Record 42 of Set 10 | zemio
# Processing Record 43 of Set 10 | jumla
# Processing Record 44 of Set 10 | san antonio
# Processing Record 45 of Set 10 | rawson
# Processing Record 46 of Set 10 | piacabucu
# Processing Record 47 of Set 10 | murgab
# Processing Record 48 of Set 10 | acapulco
# Processing Record 49 of Set 10 | altamont
# Processing Record 0 of Set 11 | parnarama
# Processing Record 1 of Set 11 | chitaga
# Processing Record 2 of Set 11 | lisakovsk
# Processing Record 3 of Set 11 | hun
# Processing Record 4 of Set 11 | yerofey pavlovich
# Processing Record 5 of Set 11 | moron
# Processing Record 6 of Set 11 | sao jose da coroa grande
# Processing Record 7 of Set 11 | ajdabiya
# Processing Record 8 of Set 11 | ahipara
# Processing Record 9 of Set 11 | vao
# Processing Record 10 of Set 11 | simao
# Processing Record 11 of Set 11 | sao miguel do araguaia
# Processing Record 12 of Set 11 | buala
# Processing Record 13 of Set 11 | tolaga bay
# Processing Record 14 of Set 11 | hopkinton
# Processing Record 15 of Set 11 | yuksekova
# Processing Record 16 of Set 11 | bonavista
# Processing Record 17 of Set 11 | storozhevaya
# Processing Record 18 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 19 of Set 11 | manokwari
# Processing Record 20 of Set 11 | port moresby
# Processing Record 21 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 11 | hervey bay
# Processing Record 23 of Set 11 | sao filipe
# Processing Record 24 of Set 11 | lampa
# Processing Record 25 of Set 11 | soubre
# Processing Record 26 of Set 11 | hovd
# Processing Record 27 of Set 11 | mandurah
# Processing Record 28 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 29 of Set 11 | piripiri
# Processing Record 30 of Set 11 | larsnes
# Processing Record 31 of Set 11 | mamaku
# Processing Record 32 of Set 11 | havelock
# Processing Record 33 of Set 11 | san policarpo
# Processing Record 34 of Set 11 | jiwani
# Processing Record 35 of Set 11 | ajmer
# Processing Record 36 of Set 11 | galveston
# Processing Record 37 of Set 11 | goderich
# Processing Record 38 of Set 11 | tual
# Processing Record 39 of Set 11 | mercedes
# Processing Record 40 of Set 11 | sheridan
# Processing Record 41 of Set 11 | goure
# Processing Record 42 of Set 11 | caranavi
# Processing Record 43 of Set 11 | te anau
# Processing Record 44 of Set 11 | xinye
# Processing Record 45 of Set 11 | omboue
# Processing Record 46 of Set 11 | torres
# Processing Record 47 of Set 11 | grand-lahou
# Processing Record 48 of Set 11 | sundargarh
# Processing Record 49 of Set 11 | asyut
# Processing Record 0 of Set 12 | le port
# Processing Record 1 of Set 12 | abu samrah
# Processing Record 2 of Set 12 | medeiros neto
# Processing Record 3 of Set 12 | bathsheba
# Processing Record 4 of Set 12 | seydi
# Processing Record 5 of Set 12 | auki
# Processing Record 6 of Set 12 | laranjeiras do sul
# Processing Record 7 of Set 12 | guaruja
# Processing Record 8 of Set 12 | hambantota
# Processing Record 9 of Set 12 | nouadhibou
# Processing Record 10 of Set 12 | port said
# Processing Record 11 of Set 12 | namatanai
# Processing Record 12 of Set 12 | fairbanks
# Processing Record 13 of Set 12 | puerto madero
# Processing Record 14 of Set 12 | nanga eboko
# Processing Record 15 of Set 12 | senno
# Processing Record 16 of Set 12 | chistogorskiy
# Processing Record 17 of Set 12 | necochea
# Processing Record 18 of Set 12 | veraval
# Processing Record 19 of Set 12 | savannah bight
# Processing Record 20 of Set 12 | itacoatiara
# Processing Record 21 of Set 12 | tourlaville
# Processing Record 22 of Set 12 | tianpeng
# Processing Record 23 of Set 12 | kapit
# Processing Record 24 of Set 12 | arruda dos vinhos
# Processing Record 25 of Set 12 | aktas
# City not found. Skipping...
# Processing Record 26 of Set 12 | mabai
# Processing Record 27 of Set 12 | pagman
# City not found. Skipping...
# Processing Record 28 of Set 12 | sobolevo
# Processing Record 29 of Set 12 | kuliyapitiya
# Processing Record 30 of Set 12 | shishou
# Processing Record 31 of Set 12 | candido mendes
# Processing Record 32 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 12 | novyye lyady
# Processing Record 34 of Set 12 | port hawkesbury
# Processing Record 35 of Set 12 | onega
# Processing Record 36 of Set 12 | mastic
# Processing Record 37 of Set 12 | shitanjing
# Processing Record 38 of Set 12 | bilibino
# Processing Record 39 of Set 12 | awbari
# Processing Record 40 of Set 12 | murray
# Processing Record 41 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 12 | moranbah
# Processing Record 43 of Set 12 | kodino
# Processing Record 44 of Set 12 | krumovgrad
# Processing Record 45 of Set 12 | ketchikan
# Processing Record 46 of Set 12 | klamath falls
# Processing Record 47 of Set 12 | santa fe
# Processing Record 48 of Set 12 | itatskiy
# Processing Record 49 of Set 12 | kuloy
# Processing Record 0 of Set 13 | kabare
# Processing Record 1 of Set 13 | quatre cocos
# Processing Record 2 of Set 13 | willowmore
# Processing Record 3 of Set 13 | ulety
# Processing Record 4 of Set 13 | grants
# Processing Record 5 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 13 | teguldet
# Processing Record 7 of Set 13 | tazovskiy
# Processing Record 8 of Set 13 | ontario
# Processing Record 9 of Set 13 | ancud
# Processing Record 10 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 11 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 13 | akyab
# City not found. Skipping...
# Processing Record 13 of Set 13 | azare
# Processing Record 14 of Set 13 | loa janan
# Processing Record 15 of Set 13 | rio grande
# Processing Record 16 of Set 13 | hirara
# Processing Record 17 of Set 13 | hay river
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert city data to dataframe and clean up
df=pd.DataFrame([{
    "City": data["name"],
    "Country": data["sys"]["country"],
    "Date": date.fromtimestamp(data['dt']).isoformat(),
    "Cloudiness": data["clouds"]["all"],
    "Humidity": data["main"]["humidity"],
    "Lat": data["coord"]["lat"],
    "Lng": data["coord"]["lon"],
    "Max Temp": data["main"]["temp_max"],
    "Wind Speed": data["wind"]["speed"]
} for data in city_data])
df.head()
# Out:
#            City Country        Date  Cloudiness  Humidity    Lat     Lng  \
# 0       Changde      CN  2020-01-07          95        71  29.04  111.68
# 1       Dunedin      NZ  2020-01-07           7        72 -45.87  170.50
# 2  Punta Arenas      CL  2020-01-07          90        81 -53.16  -70.91
# 3    Baruun-Urt      MN  2020-01-07           0        86  46.68  113.28
# 4         Airai      TL  2020-01-07          51        49  -8.93  125.41
#
#    Max Temp  Wind Speed
# 0     47.08        2.91
# 1     52.23       19.62
# 2     51.80        8.05
# 3      7.39        6.13
# 4     83.25        5.77

# %%
# Export the city data into a .csv file
df.to_csv(output_data_file)
df.count()
# Out:
# City          553
# Country       553
# Date          553
# Cloudiness    553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.rcParams["figure.figsize"] = (10,7)
c = df["Max Temp"]
plt.scatter(df["Lat"], df["Max Temp"], edgecolors="black", alpha = 0.5, marker = "o", c=c, cmap="plasma")
plt.xlabel("Latitude", fontsize="x-large")
plt.ylabel("Max Temperature ($^\circ$F)", fontsize="x-large")
plt.title("City Latitude Vs. Max Temperature ({})".format(df["Date"][0]), fontsize="x-large")
plt.grid()
plt.savefig("Output_Plots/lat_vs_maxtemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.rcParams["figure.figsize"] = (10,7)
c = df["Humidity"]
plt.scatter(df["Lat"], df["Humidity"], edgecolors="black", alpha = 0.5, marker = "o", c=c, cmap = "viridis")
plt.xlabel("Latitude", fontsize="x-large")
plt.ylabel("Humidity (%)", fontsize="x-large")
plt.title("City Latitude Vs. Humidity ({})".format(df["Date"][0]), fontsize="x-large")
plt.grid()
plt.savefig("Output_Plots/lat_vs_humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.rcParams["figure.figsize"] = (10,7)
c = df["Cloudiness"]
plt.scatter(df["Lat"], df["Cloudiness"], edgecolors="black", alpha = 0.5, marker = "o", c=c, cmap="winter")
plt.xlabel("Latitude", fontsize="x-large")
plt.ylabel("Cloudiness (%)", fontsize="x-large")
plt.title("City Latitude Vs. Cloudiness ({})".format(df["Date"][0]), fontsize="x-large")
plt.grid()
plt.savefig("Output_Plots/lat_vs_cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.rcParams["figure.figsize"] = (10,7)
c = df["Wind Speed"]
plt.scatter(df["Lat"], df["Wind Speed"], edgecolors='black', alpha = 0.5, marker = "o",c=c, cmap="autumn")
plt.xlabel("Latitude", fontsize="x-large")
plt.ylabel("Wind Speed (MPH)", fontsize="x-large")
plt.title("City Latitude Vs. Wind Speed ({})".format(df["Date"][0]), fontsize="x-large")
plt.grid()
plt.savefig("Output_Plots/lat_vs_windspeed.png")
plt.show()

# %% [markdown]
# ## WeatherPy Data Analysis Report
# Following were the trends observed after the analysis:
